# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio
from PIL import Image
from Propagation import *

# %%
image=imageio.imread('4.png')[359:471,359:471]
image1=Image.fromarray(image)
image1=image1.resize((280,280),resample=0)
image3=np.array(image1)

image2=np.zeros((4000,4000))
image2[1860:2140,1860:2140]=image3

plt.imshow(image2)
plt.colorbar()
plt.show()

# %%
out=prop(image2,0.124)
plt.imshow(np.abs(out))
plt.show()

# %%
plt.imshow(np.abs(out)[1560:2440,1560:2440])
plt.show()
